# %%
x=10
if x>5:
  ('x is greater than5')

# %%
x = 3

if x % 2 == 0:
    print("x is even")
else:
    print("x is odd")
# Out:
# x is odd

# %%
name=input("enter your name ")
course=input("enter your course")
rollno=int(input("enter your roll number"))
branch=input("enter your branch")
S1=int(input("enter your marks "))
S2=int(input("enter your marks "))
S3=int(input("enter your marks "))
S4=int(input("enter your marks "))
S5=int(input("enter your marks "))
percentage= ((S1+S2+S3+S4+S5)/5)*100
if percentage >=80:
    print("you will be a part of A0 batch")
elif percentage>=60 and marks<80:
    print("you will be a part of A1 batch")
elif percentage>=40 and marks<60:
    print("you will be a part of A2 batch")
else:
    print("you will be a part of A3 batch")
# Out:
# enter your name Himanshi
# enter your courseBtech
# enter your roll number57484
# enter your branchAiml
# enter your marks 67
# enter your marks 76
# enter your marks 98
# enter your marks 67
# enter your marks 87
# you will be a part of A0 batch

# %%
nums = [1, 2, 3, 4]

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
type(nums)
# Out:
# list

# %%
nums[0]
# Out:
# 1
