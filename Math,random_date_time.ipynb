# %%
import math

# %%
import math

num = 25
print (math.sqrt(num))
# Out:
# 5.0

# %%
print (math.pow(2,5))
# Out:
# 32.0

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
import random
print(random.radiant(1,0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2130/2843606592.py in <cell line: 0>()
#       1 import random
# ----> 2 print(random.radiant(1,0))
#
# AttributeError: module 'random' has no attribute 'radiant'

# %%
print(random.random())
# Out:
# 0.45619902434519044

# %%
import random
fruits = ["apple","banana","mango","orange"]

# %%
number =[1,2,3,4]
random.shuffle(number)
print(number)
# Out:
# [2, 1, 3, 4]

# %%
print(random.uniform(1,10))
# Out:
# 4.193627088218177

# %%
print(random.choice([True,False]))
# Out:
# False

# %%
otp = random.randint(1000,9999)
print("otp=",otp)
# Out:
# otp= 5911

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:24:40.287133

# %%
print(datetime .date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:28:52.635860

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().second)
# Out:
# 9

# %%
print(datetime.datetime.now().minute)
# Out:
# 39

# %%
#Custom

# %%
t= datetime. time(10,30,45)
print(t)
# Out:
# 10:30:45

# %%
date1=datetime.date(2026,7,9)
date2=datetime.date(2026,8,19)

print(date2-date1)
# Out:
# 41 days, 0:00:00

# %%
today =datetime.datetime.now()
print(today.strftime("%d-%m-%y)"
# Out:
#   File "/tmp/ipykernel_2130/401956160.py", line 4
#
#     ^
# SyntaxError: incomplete input

# %%
today = datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday
