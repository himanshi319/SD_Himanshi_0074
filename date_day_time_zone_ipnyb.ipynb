# %%
import time
from IPython.display import clear_output
from datetime import datetime

while True:
   clear_output(wait=True)
   current_time = datetime.now().strftime("%I:%M:%S %p")
   print("DIGITAL CLOCK")
   print (current_time)
   time.sleep(1)
# Out:
# DIGITAL CLOCK
# 08:48:19 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_817/559573170.py in <cell line: 0>()
#       8    print("DIGITAL CLOCK")
#       9    print (current_time)
# ---> 10    time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import zoneInfo
while True:
      clear_output(wait= true)

      ist_time= datetime.now(ZoneInfo("Asia/kalkata"))


print(" DIGITAL CLOCK")
print("Date:"ist_time.strftime("%d-%m-%y"))
print("Day:"ist_time.strf.time("%A"))
print("Time:"ist_time.strftime("%I:%S:%M:%p"))
print("Zone:","Indian Standard Time(IST)")
time.sleep(1)
# Out:
#   File "/tmp/ipykernel_817/1528389847.py", line 12
#     print("Date:"ist_time.strftime("%d-%m-%y"))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
