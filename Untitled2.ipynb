# %%
import math

# %%
num=25
print(math.sqrt((num)) )
# Out:
# 5.0

# %%
print(math.gcd(24,360))
# Out:
# 24

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math. radians(90)))
# Out:
# 1.0

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
print(random.radiant(1,0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_887/1573392161.py in <cell line: 0>()
# ----> 1 print(random.radiant(1,0))
#
# NameError: name 'random' is not defined
