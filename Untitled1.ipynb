# %%
L=[23.4,45,'book',345,456]

# %%
L[4].real
# Out:
# 456

# %%
L[0:5:4]
# Out:
# [23.4, 456]

# %%
L[0]
# Out:
# 23.4

# %%
L[-1:-3:-2]
# Out:
# [456]

# %%
S="maritimeexpertise"

# %%
L+S
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_537/2163280024.py in <cell line: 0>()
# ----> 1 L+S
#
# TypeError: can only concatenate list (not "str") to list

# %%
L+list(S)
# Out:
# [23.4,
#  45,
#  'book',
#  345,
#  456,
#  'm',
#  'a',
#  'r',
#  'i',
#  't',
#  'i',
#  'm',
#  'e',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  't',
#  'i',
#  's',
#  'e']

# %%
L[2][0:2]
# Out:
# 'bo'

# %%
L[4]
# Out:
# 456

# %%
L1=['book',1,5,]

# %%
L+L1
# Out:
# [23.4, 45, 'book', 345, 456, 'book', 1, 5]

# %%
L1*3
# Out:
# ['book', 1, 5, 'book', 1, 5, 'book', 1, 5]

# %%
len(L1)
# Out:
# 3

# %%
L
# Out:
# [23.4, 45, 'book', 345, 456]

# %%
L1.append(S)

# %%
S
# Out:
# 'maritimeexpertise'

# %%
L1
# Out:
# ['book', 1, 5, 'maritimeexpertise', 'maritimeexpertise']

# %%
A=['school']

# %%
L+list(A)
# Out:
# [23.4, 45, 'book', 345, 456, 'school']

# %%
L.extend('book')

# %%
L
# Out:
# [23.4, 45, 'book', 345, 456, 'b', 'o', 'o', 'k']

# %%
L1
# Out:
# ['book', 1, 5, 'maritimeexpertise', 'maritimeexpertise']

# %%
L1.insert(1,"book")

# %%
L1
# Out:
# ['book', 'book', 1, 5, 'maritimeexpertise', 'maritimeexpertise']

# %%
L3=[6,7,8,9]

# %%
L.append(L3)

# %%
L
# Out:
# [23.4, 45, 'book', 345, 456, 'b', 'o', 'o', 'k', [6, 7, 8, 9]]

# %%
L1.pop()
# Out:
# 'maritimeexpertise'

# %%
D=[1,2,8,9]

# %%
D.sort()

# %%
D
# Out:
# [1, 2, 8, 9]

# %%
D.remove(8)

# %%
D
# Out:
# [1, 2, 9]

# %%
D.sort(reverse=True)

# %%
D
# Out:
# [9, 2, 1]

# %%
D.reverse()

# %%
D
# Out:
# [1, 2, 9]

# %%
D.sort()

# %%
D
# Out:
# [1, 2, 9]

# %%
H2=[45,54,67,56,87,8,9]

# %%
H2.sort()

# %%
H2
# Out:
# [8, 9, 45, 54, 56, 67, 87]

# %%
F=[1,2,5,2,6]

# %%
F. count(2)
# Out:
# 2

# %%
F.index(2)
# Out:
# 1

# %%
L=[1,4,'ram',56]

# %%
 L.replace('r', 'a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_537/1362609192.py in <cell line: 0>()
# ----> 1 L.replace('r', 'a')
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
T=(1,4,5,6,)

# %%
type(T)
# Out:
# tuple

# %%
len(T)
# Out:
# 4

# %%
T[0]
# Out:
# 1

# %%
T[-1]
# Out:
# 6

# %%
T.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_537/1271648174.py in <cell line: 0>()
# ----> 1 T.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_537/760133295.py in <cell line: 0>()
# ----> 1 T.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
T*3
# Out:
# (1, 4, 5, 6, 1, 4, 5, 6, 1, 4, 5, 6)

# %%
S1={1,6,8,9,7,5}

# %%
type(S1)
# Out:
# set

# %%
S2={}

# %%
type(S2)
# Out:
# dict

# %%
S3={324,456,456,"sudh",45+45j,34.465,(3,4,5)}

# %%
S3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
S3.pop()
# Out:
# 'sudh'

# %%
D6=[2,5,8,9,'bag']

# %%
D6=set(list(D6))

# %%
D6
# Out:
# {2, 5, 8, 9, 'bag'}

# %%
D6.add(0)

# %%
D6
# Out:
# {0, 2, 5, 8, 9, 'bag'}

# %%
D6={0,2,5,8,9,'bag'}

# %%
list(D6)[1::6]
# Out:
# [2]

# %%
D6[1::6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_605/4054913531.py in <cell line: 0>()
# ----> 1 D6[1::6]
#
# TypeError: 'set' object is not subscriptable

# %%
reversed_list = sorted(D6, reverse=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_605/2362197931.py in <cell line: 0>()
# ----> 1 reversed_list = sorted(D6, reverse=True)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
D6.remove(8)

# %%
D6
# Out:
# {0, 2, 5, 9, 'bag'}

# %%
d={"name" : "himanshi"}

# %%
type(d)
# Out:
# dict

# %%
d1={'key':"sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name':"sudansh","email" : "ss@gmail.com","number":664578}

# %%
C=d2['name']

# %%
C
# Out:
# 'sudansh'

# %%
d2['name']='rohit'

# %%
d2
# Out:
# {'name': 'rohit', 'email': 'ss@gmail.com', 'number': 664578}

# %%
d2['name']
# Out:
# 'rohit'

# %%
d2['email']
# Out:
# 'ss@gmail.com'
