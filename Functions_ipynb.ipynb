# %%
def sum_two_numbers(a, b):
    return a + b

# %%
def test():
 pass

# %%
def test1():
 print ("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1 + "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2290/576725596.py in <cell line: 0>()
# ----> 1 test1 + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'function' and 'str'

# %%
def test1():
     return (" this is my very very first function")

# %%
def test3():
   return "sudh",23,46.4,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 46.4, [1, 2, 3, 3])

# %%
a,b,c,d=test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 46.4

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
a,b=1,2

# %%
def add():
  a=10+11/3
  return a

# %%
add()
# Out:
# 13.666666666666666

# %%
def add(a,b,c):
  d= (a+b/c)
  return d

# %%
add(4,5,6.8)
# Out:
# 4.735294117647059

# %%
def test6(a,b):
   return a+b

# %%
test6(2,3)
# Out:
# 5

# %%
def test(a,b):
  c=a+b
  return c
a= eval(input("input enter tuple"))
b=eval(input("input enter tuple"))
# Out:
# input enter tuple(2,3,4)
# input enter tuple4,5,6

# %%
def test11(*args):
  return args +(1,2,3,4)

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3, 1, 2, 3, 4)

# %%
test11
# Out:
# <function __main__.test11(*args)>

# %%
def test11(*kwargs):
   return kwargs+[1,2,3,4]

# %%
test11(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2290/319663502.py in <cell line: 0>()
# ----> 1 test11(1,2,3,4)
#
# /tmp/ipykernel_2290/1737891911.py in test11(*kwargs)
#       1 def test11(*kwargs):
# ----> 2    return kwargs+[1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
test11(1,2,3,"sudh",5,6,[1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2290/2900831078.py in <cell line: 0>()
# ----> 1 test11(1,2,3,"sudh",5,6,[1,2,3,4])
#
# /tmp/ipykernel_2290/1737891911.py in test11(*kwargs)
#       1 def test11(*kwargs):
# ----> 2    return kwargs+[1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test12(*sudh):
  return sudh
  test12(8)

# %%
test12(1,2,3,45)
# Out:
# (1, 2, 3, 45)

# %%
def test13(*args,a):
  return args,a

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
test13(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2290/1205117932.py in <cell line: 0>()
# ----> 1 test13(3)
#
# NameError: name 'test13' is not defined

# %%
def test13(b, c, d, e, a=2):
    return a, b, c, d

# %%
test13(2,5,10,20,a=234)
# Out:
# (234, 2, 5, 10)

# %%
def test15(**kwargs):
  return kwargs

# %%
type(test15())
# Out:
# dict

# %%
test15 (a=[1,2,3,4],b="sudh", c=23.6)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.6}

# %%
def calc(a, d, c):
    if c == "+":
        print(a + d)
    elif c == "-":
        print(a - d)
    elif c == "*":
        print(a * d)
    elif c == "/":
        print(a / d)
        return "done"

n1 = int(input("enter num1: "))
n2 = int(input("enter num2: "))
op = input("enter opt: ")


calc(n1, n2, op)
# Out:
# enter num1: 45
# enter num2: 4
# enter opt: 67

# %%
def wid():
  amount = int(input("Enter Amount: "))


  if amount <= 0:
    print("Invalid Amount")

  elif amount > accounts[card]["balance"]:
    print("Insufficient Funds")
    print("Balance:", accounts[card]["balance"])

  else:
    atm_cash = 6000

  if amount > atm_cash:
    print("ATM Out of Cash")

  else:
    accounts[card]["balance"] -= amount
    print("Please Collect Your Cash")
    print("Updated Balance:", accounts[card]["balance"])
def dep():
  amount = int(input("Enter Deposit Amount: "))

  if amount <= 0:
    print("Invalid Amount")

  else:
    accounts[card]["balance"] += amount
    print("Deposit Successful")
    print("Updated Balance:", accounts[card]["balance"])
def bal():
  print("Current Balance:", accounts[card]["balance"])


accounts = {
    "1234567890": {"pin": "1234", "balance": 5000},
    "9876543210": {"pin": "4321", "balance": 10000}
}

card = input("Enter Card Number: ")

if card in accounts:
    pin = input("Enter PIN: ")

    if pin == accounts[card]["pin"]:

        while True:
            print("\n----- ATM MENU -----")
            print("1. Withdraw")
            print("2. Deposit")
            print("3. Balance Inquiry")
            print("4. Exit")

            choice = input("Enter your choice: ")
            if choice == "1":
                wid()
            elif choice == "2":
                dep()
            elif choice == "3":
                bal()
            elif choice == "4":
                print("Card Ejected")
                print("Thank You!")
                break

            else:
                print("Invalid Choice")

            receipt = input("Print Receipt? (y/n): ")
            if receipt.lower() == "y":
                print("----- RECEIPT -----")
                print("Balance:", accounts[card]["balance"])

            again = input("Another Transaction? (y/n): ")
            if again.lower() != "y":
                print("Card Ejected")
                print("Thank You!")
                break

    else:
        print("Incorrect PIN")
        print("Card Ejected")

else:
    print("Invalid Card Number")
# Out:
# Enter Card Number: 1234567890
# Enter PIN: 1234
#
# ----- ATM MENU -----
# 1. Withdraw
# 2. Deposit
# 3. Balance Inquiry
# 4. Exit
# Enter your choice: 2
# Enter Deposit Amount: 3000
# Deposit Successful
# Updated Balance: 8000
# Print Receipt? (y/n): Fxgctv
# Another Transaction? (y/n): Trw
# Card Ejected
# Thank You!

# %%
def deposit():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be deposited: "))
    customer["Amount"] = customer["Amount"] + money
def withdrawal():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be withdrawn: "))
    if customer["Amount"] < money:
      print("Not enough balance")
      return customer['Amount']
    else:
      customer["Amount"] = customer["Amount"] - money
      return customer["Amount"]
def amount():
  print(customer["Amount"])

def pin_change():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    npin = int(input("Enter new PIN: "))
    n2pin = int(input("Confirm PIN: "))
    if npin != n2pin:
      print("Not same")
    else:
      print("PIN changed succesfully")

customer = {"Card number" : 1234 , "PIN" : 789 , "Amount" : 4500 }
cnum = int(input("Enter Card number: "))
if cnum != customer["Card number"]:
  print("Invalid Card Number")
else:
  p = 1
  while p==1:
    service = int(input("Services :\n 1-DEPOSIT \n 2-WITHDRAWAL \n 3-PIN CHANGE \n 4-AMOUNT CHECK \n 5-EXIT \n Enter Service: "))
    if service == 1:
      deposit()
    elif service == 2:
      print("new amount :" ,withdrawal())
    elif service == 3:
      pin_change()
    elif service == 4:
      amount()
    elif service == 5:
      p=0
      print("THANKS FOR USING SERVICES...")
      break
    else:
      print("Invalid choice")
    inp = input("more services?(Y/N): ")
    if inp == 'N' or inp == 'n':
      p = 0
# Out:
# new amount : 3940
# 3940
